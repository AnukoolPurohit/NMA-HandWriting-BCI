# %% [markdown]
# # Setup

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append("/home/anukoolpurohit/Documents/Workspace/Nueromatch/NMA-DL/HandwritingBCI")

# %%
from handwritingBCI import Path
from handwritingBCI.utils import get_dataset
import numpy as np

# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
PATH = Path("/home/anukoolpurohit/Documents/AnukoolPurohit/Datasets/HandwritingBCI/handwriting-bci/handwritingBCIData")

# %%
dataset, labels = get_dataset(PATH)

# %%
print(dataset.shape, len(labels))
# Out:
# (3627, 201, 192) 3627

# %%
def plot_electrode_data(dataset, index, figsize=(15, 15)):
    plt.figure(figsize=figsize)
    plt.imshow(dataset[index].T)
    plt.title(labels[index],size=100)
    plt.show()

# %%
plot_electrode_data(dataset, 100)

# %%
import torch
from torch.utils.data import Dataset, dataloader
